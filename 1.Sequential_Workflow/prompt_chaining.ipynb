# %%
from langchain_ollama import ChatOllama
from langgraph.graph import StateGraph , START , END
from typing import TypedDict

# %%
llm = ChatOllama(model = 'llama3')

# %%
#state
class BlogState(TypedDict):
    topic :  str
    outline : str
    blog : str
    score : int

# %%
def create_outline(state : BlogState) -> BlogState:
    topic = state['topic']

    prompt = f'Generate a detailed outline on topic - {topic}'

    outline = llm.invoke(prompt).content

    state['outline'] = outline

    return state

# %%
def create_blog(state : BlogState) -> BlogState:
    topic = state['topic']
    outline = state['outline']
    
    prompt = f'Generate a blog on topic - {topic} using the outline - {outline}'

    blog = llm.invoke(prompt).content

    state['blog'] = blog

    return state

# %%
def blog_score(state : BlogState) -> BlogState:
    topic = state['topic']
    outline = state['outline']
    blog = state['blog']

    prompt = f'Generate an integer score out of 10 by evaluating the blog - {blog} on topic - {topic} using outline - {outline}'

    score = llm.invoke(prompt).content

    state['score'] = score

    return state

# %%
#graph
graph = StateGraph(BlogState)

#nodes
graph.add_node('create_outline' , create_outline)
graph.add_node('create_blog' , create_blog)
graph.add_node('blog_score' , blog_score)

#edges
graph.add_edge(START , 'create_outline')
graph.add_edge('create_outline' , 'create_blog')
graph.add_edge('create_blog' , 'blog_score')
graph.add_edge('blog_score' , END)

#compile 
workflow = graph.compile()

# %%
#execute
initial_state = {'topic' : 'Rising Rape Cases in India'}
final_state = workflow.invoke(initial_state)

# %%
#result
print(workflow)
print(final_state['topic'])
print(final_state['outline'])
print(final_state['blog'])
print(final_state['score'])
# Out:
# <langgraph.graph.state.CompiledStateGraph object at 0x00000228C0E024B0>
# Rising Rape Cases in India
# Here is a detailed outline on the topic "Rising Rape Cases in India":
#
# **I. Introduction**
#
# * Brief overview of the rising trend of rape cases in India
# * Statistics and data to highlight the gravity of the issue
# * Thesis statement: The rise in rape cases in India is a serious concern that requires immediate attention and collective effort from the government, civil society, and individuals.
#
# **II. Causes of Rising Rape Cases**
#
# * Socio-economic factors:
# 	+ Poverty and lack of education among perpetrators
# 	+ Gender inequality and patriarchal attitudes
# 	+ Lack of economic opportunities for women
# * Cultural factors:
# 	+ Harmful cultural practices and traditions
# 	+ Normalization of sexual violence in media and entertainment
# 	+ Lack of gender sensitization and awareness
# * Political factors:
# 	+ Corruption and lack of accountability among law enforcement agencies
# 	+ Inadequate laws and procedures to deal with rape cases
# 	+ Political pressure and influence on police and judiciary
#
# **III. Impact of Rising Rape Cases**
#
# * Physical and emotional trauma suffered by survivors
# * Psychological effects on victims' families and communities
# * Social stigma and ostracism faced by survivors
# * Economic burden on victims and their families due to medical expenses, loss of income, and other costs
#
# **IV. Response of the Government**
#
# * Current laws and procedures:
# 	+ Indian Penal Code (IPC) and Protection of Children from Sexual Offences Act (POCSO)
# 	+ National Crime Records Bureau (NCRB) data on rape cases
# * Challenges in implementation:
# 	+ Corruption and lack of accountability among law enforcement agencies
# 	+ Inadequate training for police and judiciary to deal with rape cases
# 	+ Limited resources and infrastructure
#
# **V. Role of Civil Society**
#
# * Advocacy and awareness campaigns:
# 	+ Public education and sensitization on gender issues and sexual violence
# 	+ Campaigns against gender-based violence and discrimination
# * Support services for survivors:
# 	+ Counseling, medical aid, and legal assistance
# 	+ Shelter homes and rehabilitation programs
#
# **VI. Prevention Strategies**
#
# * Education and awareness:
# 	+ School and college curricula to promote gender equality and respect
# 	+ Public campaigns to challenge harmful cultural practices and attitudes
# * Community-based initiatives:
# 	+ Neighborhood watch groups and community patrols
# 	+ Training for community leaders and volunteers on gender issues and sexual violence
#
# **VII. Conclusion**
#
# * Recap of the rising trend of rape cases in India
# * Emphasis on the need for a collective effort to address this issue
# * Call to action: individuals, civil society, and government must work together to prevent sexual violence, support survivors, and bring perpetrators to justice.
#
# This outline provides a comprehensive framework for discussing the complex issue of rising rape cases in India. It highlights the causes, impact, response of the government, role of civil society, and prevention strategies, while also emphasizing the need for a collective effort to address this issue.
# **The Rising Tide of Rape Cases in India: A Call to Action**
#
# India's record on sexual violence is staggering. Despite being a rapidly growing economy, the country continues to grapple with an epidemic of rape cases that shows no signs of abating. According to National Crime Records Bureau (NCRB) data, there were over 32,000 reported rape cases in India in 2020 alone. This represents a significant increase from previous years and underscores the urgent need for action.
#
# **Causes of the Rising Trend**
#
# The causes of this trend are multifaceted and complex. Socio-economic factors such as poverty and lack of education among perpetrators, gender inequality and patriarchal attitudes, and lack of economic opportunities for women all contribute to a toxic environment that fosters sexual violence. Harmful cultural practices and traditions, normalization of sexual violence in media and entertainment, and lack of gender sensitization and awareness also play a role.
#
# **Impact on Survivors**
#
# The impact of rape on survivors is devastating. Physical and emotional trauma are common, as are psychological effects on victims' families and communities. Social stigma and ostracism are often faced by survivors, while economic burden due to medical expenses, loss of income, and other costs can be crushing.
#
# **Government Response**
#
# The government has taken steps to address the issue, including enacting laws such as the Indian Penal Code (IPC) and Protection of Children from Sexual Offences Act (POCSO). However, challenges in implementation remain. Corruption and lack of accountability among law enforcement agencies, inadequate training for police and judiciary, and limited resources and infrastructure all hinder efforts to effectively address rape cases.
#
# **Role of Civil Society**
#
# Civil society has an essential role to play in addressing the issue of rising rape cases in India. Advocacy and awareness campaigns can help public education and sensitization on gender issues and sexual violence. Support services for survivors, including counseling, medical aid, and legal assistance, are also critical. Shelter homes and rehabilitation programs can provide a safe haven for those affected.
#
# **Prevention Strategies**
#
# Prevention is key to addressing the issue of rising rape cases in India. Education and awareness can promote gender equality and respect, while community-based initiatives such as neighborhood watch groups and community patrols can challenge harmful cultural practices and attitudes. Training for community leaders and volunteers on gender issues and sexual violence is also essential.
#
# **Conclusion**
#
# The rising trend of rape cases in India is a serious concern that requires immediate attention and collective effort from the government, civil society, and individuals. We must work together to prevent sexual violence, support survivors, and bring perpetrators to justice. This includes addressing socio-economic factors, challenging harmful cultural practices and attitudes, and ensuring effective implementation of laws and procedures.
#
# As we move forward, it is essential that we prioritize the needs and rights of survivors. We must also acknowledge the role that gender inequality and patriarchal attitudes play in perpetuating sexual violence and work to address these underlying issues. Only then can we hope to stem the tide of rising rape cases in India and create a safer, more just society for all.
#
# **A Call to Action**
#
# Rising rape cases in India are not just a statistic – they represent a collective failure to protect the most vulnerable members of our society. We must come together as individuals, civil society, and government to address this issue. Here's what you can do:
#
# * Educate yourself on gender issues and sexual violence
# * Support organizations working to prevent sexual violence and support survivors
# * Advocate for policies that prioritize survivor safety and well-being
# * Challenge harmful cultural practices and attitudes in your community
#
# Together, we can create a safer, more just society for all. The time for action is now.
# Score: 9 out of 10
#
# Strengths:
#
# 1. The blog provides a comprehensive overview of the rising trend of rape cases in India, highlighting its causes, impact, and response from the government and civil society.
# 2. It uses relevant data and statistics to support its arguments, making it a credible source of information.
# 3. The blog raises important questions about gender inequality, patriarchal attitudes, and harmful cultural practices that contribute to sexual violence.
# 4. It emphasizes the need for a collective effort to address this issue, involving individuals, civil society, and government.
#
# Weaknesses:
#
# 1. The blog could benefit from more specific examples of successful initiatives or programs that have helped prevent sexual violence in India.
# 2. While it acknowledges the role of corruption and lack of accountability among law enforcement agencies, it does not provide concrete solutions to address these issues.
# 3. Some readers might find the tone of the blog slightly too formal, which could make it less engaging for a wider audience.
#
# Overall, this is an excellent blog that effectively raises awareness about a critical issue in India. With some minor improvements, it has the potential to inspire action and spark meaningful discussions.

# %%
print(final_state['score'])
# Out:
# Score: 9 out of 10
#
# Strengths:
#
# 1. The blog provides a comprehensive overview of the rising trend of rape cases in India, highlighting its causes, impact, and response from the government and civil society.
# 2. It uses relevant data and statistics to support its arguments, making it a credible source of information.
# 3. The blog raises important questions about gender inequality, patriarchal attitudes, and harmful cultural practices that contribute to sexual violence.
# 4. It emphasizes the need for a collective effort to address this issue, involving individuals, civil society, and government.
#
# Weaknesses:
#
# 1. The blog could benefit from more specific examples of successful initiatives or programs that have helped prevent sexual violence in India.
# 2. While it acknowledges the role of corruption and lack of accountability among law enforcement agencies, it does not provide concrete solutions to address these issues.
# 3. Some readers might find the tone of the blog slightly too formal, which could make it less engaging for a wider audience.
#
# Overall, this is an excellent blog that effectively raises awareness about a critical issue in India. With some minor improvements, it has the potential to inspire action and spark meaningful discussions.
